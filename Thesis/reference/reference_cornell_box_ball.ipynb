# %% [markdown]
# ## Cornell Box Demo Scene (Mitsuba)

# %%
import matplotlib.pyplot as plt
import mitsuba as mi
mi.variants()
#mi.set_variant("cuda_ad_rgb")
mi.set_variant("scalar_rgb")

def show_img(img):
    plt.axis("off")
    plt.imshow(img ** (1.0 / 2.2))

# %%
scene = mi.load_file(".\\scenes\\cbox.xml")
img = mi.render(scene, spp=256)

show_img(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Simple Teapot Scene (Mitsuba)

# %%
scene = mi.load_file(".\\scenes\\simple.xml")
img = mi.render(scene, spp=256)

show_img(img)

# %%
params = mi.traverse(scene)
print(params)
# Out:
# SceneParameters[
#   ----------------------------------------------------------------------------------------
#   Name                                 Flags    Type           Parent
#   ----------------------------------------------------------------------------------------
#   sensor.near_clip                              float          PerspectiveCamera
#   sensor.far_clip                               float          PerspectiveCamera
#   sensor.shutter_open                           float          PerspectiveCamera
#   sensor.shutter_open_time                      float          PerspectiveCamera
#   sensor.film.size                              ScalarVector2u HDRFilm
#   sensor.film.crop_size                         ScalarVector2u HDRFilm
#   sensor.film.crop_offset                       ScalarPoint2u  HDRFilm
#   sensor.x_fov                         ∂, D     Float          PerspectiveCamera
#   sensor.principal_point_offset_x      ∂, D     Float          PerspectiveCamera
# ...

# %% [markdown]
# ## My Reference Geometry (Mitsuba)

# %%
scene = mi.load_file(".\\scenes\\my_reference.xml")
img = mi.render(scene, spp=256)

show_img(img)
#mi.variants()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
